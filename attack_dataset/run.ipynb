# %% [markdown]
# # MNIST

# %%
import os
import sys

SAMPLE_SIZE = 2
# 1. Detect OS and set NUM_TEST_SAMPLES environment variable
if sys.platform.startswith("win"):
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # Windows value
elif sys.platform == "darwin":
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # macOS value
else:
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # Linux value


# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnist')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file

# %run mnist_dnn_cnn_test.py

# %run mnist_yolo_test.py
# %run mnist_mobilenet_test.py

# %run mnist_qwen_test.py
#%run mnist_moondream_test.py

# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)
# Out:
# Loading MNIST...
# Test samples: 10000
#
# Loading: Qwen/Qwen2-VL-2B-Instruct
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading pretrained config for `Qwen/Qwen2-VL-2B-Instruct` from `transformers`...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Attack dataset project\dataset-project\attack_dataset\mnist\mnist_qwen_test.py:776
#     774 from calflops import calculate_flops_hf
#     775 batch_size, max_seq_length = 1, 128
# --> 776 flops, macs, params = calculate_flops_hf(model_name=MODEL_ID,
#     777                                           input_shape=(batch_size, max_seq_length))
#     779 MODEL_FLOPS = flops
#     782 print(
#     783     f"Parameters: "
#     784     f"{MODEL_PARAMETERS:,}"
#     785 )
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\calflops\flops_counter_hf.py:100, in calculate_flops_hf(model_name, empty_model, input_shape, trust_remote_code, access_token, forward_mode, include_backPropagation, compute_bp_factor, print_results, print_detailed, output_as_string, output_precision, output_unit, ignore_modules, return_results)
#      98     assert len(input_shape) >= 1, "input_shape must have at least one element"
#      99     assert len(input_shape) == 2, "the format of input_shape must be (batch_size, seq_len) if model is transformers model and auto_generate_transformers_input if True"
# --> 100     kwargs = generate_transformer_input(input_shape=input_shape,
#     101                                         model_tokenizer=tokenizer,
#     102                                         device=device)
#     103 else:
#     104     kwargs = generate_transformer_input(input_shape=None,
#     105                                         model_tokenizer=tokenizer,
#     106                                         device=device)
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\calflops\utils.py:115, in generate_transformer_input(model_tokenizer, input_shape, device)
#     113 inp_seq = ""
#     114 for _ in range(input_shape[0]):
# --> 115     inputs = model_tokenizer.encode_plus(
#     116         inp_seq,
#     117         add_special_tokens=True,
#     118         truncation_strategy='longest_first',
#     119     )
#     120     origin_length = len(inputs["input_ids"])
#     121     padding_length = max_length - origin_length
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\transformers\tokenization_utils_base.py:3096, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3067 """
#    3068 Tokenize and prepare for the model a sequence or a pair of sequences.
#    3069
#    (...)   3084         method).
#    3085 """
#    3087 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3088     padding=padding,
#    3089     truncation=truncation,
#    (...)   3093     **kwargs,
#    3094 )
# -> 3096 return self._encode_plus(
#    3097     text=text,
#    3098     text_pair=text_pair,
#    3099     add_special_tokens=add_special_tokens,
#    3100     padding_strategy=padding_strategy,
#    3101     truncation_strategy=truncation_strategy,
#    3102     max_length=max_length,
#    3103     stride=stride,
#    3104     is_split_into_words=is_split_into_words,
#    3105     pad_to_multiple_of=pad_to_multiple_of,
#    3106     padding_side=padding_side,
#    3107     return_tensors=return_tensors,
#    3108     return_token_type_ids=return_token_type_ids,
#    3109     return_attention_mask=return_attention_mask,
#    3110     return_overflowing_tokens=return_overflowing_tokens,
#    3111     return_special_tokens_mask=return_special_tokens_mask,
#    3112     return_offsets_mapping=return_offsets_mapping,
#    3113     return_length=return_length,
#    3114     verbose=verbose,
#    3115     split_special_tokens=kwargs.pop("split_special_tokens", self.split_special_tokens),
#    3116     **kwargs,
#    3117 )
#
# TypeError: transformers.tokenization_utils_fast.PreTrainedTokenizerFast._encode_plus() got multiple values for keyword argument 'truncation_strategy'
# ========================================================================
# TEST CONFIGURATION
# ========================================================================
# Transformers: 4.56.1
# Model: fal/moondream2-docci-instruct
# Revision: 3ec40c7b6b5d87bc0c51edee45e21f5f29b449d8
# Device: cuda
# Data type: torch.bfloat16
# GPU: NVIDIA GeForce RTX 4070 Ti SUPER
#
# Loading tokenizer...
# Tokenizer loaded.
#
# Loading fal/moondream2-docci-instruct directly...
# Forced AutoModel implementation: moondream.Moondream
# PhiForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly defined. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Applied GenerationMixin compatibility patch.
# Applied PhiForCausalLM forward compatibility patch.
# Loading pretrained config for `fal/moondream2-docci-instruct` from `transformers`...
# moondream.py: 0.00B [00:00, ?B/s]
# vision.py: 0.00B [00:00, ?B/s]
# layers.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - layers.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# image_crops.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - image_crops.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# config.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - config.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - vision.py
# - layers.py
# - image_crops.py
# - config.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# text.py: 0.00B [00:00, ?B/s]
# rope.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - rope.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - text.py
# - rope.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# utils.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# lora.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - lora.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# region.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - region.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/vikhyatk/moondream2:
# - moondream.py
# - vision.py
# - text.py
# - utils.py
# - lora.py
# - region.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\Attack dataset project\dataset-project\attack_dataset\mnist\mnist_moondream_test.py:1147
#    1145 from calflops import calculate_flops_hf
#    1146 batch_size, max_seq_length = 1, 128
# -> 1147 flops, macs, params = calculate_flops_hf(model_name=MODEL_ID,
#    1148                                           input_shape=(batch_size, max_seq_length))
#    1149 MODEL_FLOPS = flops
#    1152 print(
#    1153     "\nModel ready."
#    1154 )
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\calflops\flops_counter_hf.py:77, in calculate_flops_hf(model_name, empty_model, input_shape, trust_remote_code, access_token, forward_mode, include_backPropagation, compute_bp_factor, print_results, print_detailed, output_as_string, output_precision, output_unit, ignore_modules, return_results)
#      44 """Returns the total floating-point operations, MACs, and parameters of a model.
#      45
#      46 Args:
#    (...)     73     The number of floating-point operations, multiply-accumulate operations (MACs), and parameters in the model.
#      74 """
#      76 if empty_model == None:
# ---> 77     empty_model = create_empty_model(model_name=model_name,
#      78                                      library_name=None,
#      79                                      trust_remote_code=trust_remote_code,
#      80                                      access_token=access_token)
#      82 tokenizer = AutoTokenizer.from_pretrained(model_name,
#      83                                           trust_remote_code=trust_remote_code,
#      84                                           access_token=access_token)
#      86 assert isinstance(empty_model, nn.Module), "model must be a PyTorch module"
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\calflops\estimate.py:123, in create_empty_model(model_name, library_name, trust_remote_code, access_token)
#     121             if value is not None:
#     122                 constructor = getattr(transformers, value)
# --> 123         model = constructor.from_config(config, trust_remote_code=trust_remote_code)
#     124 elif library_name == "timm":
#     125     if not is_timm_available():
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\transformers\models\auto\auto_factory.py:444, in _BaseAutoModelClass.from_config(cls, config, **kwargs)
#     442 else:
#     443     repo_id = config.name_or_path
# --> 444 model_class = get_class_from_dynamic_module(class_ref, repo_id, **kwargs)
#     445 # This block handles the case where the user is loading a model with `trust_remote_code=True`
#     446 # but a library model exists with the same name. We don't want to override the autoclass
#     447 # mappings in this case, or all future loads of that model will be the remote code model.
#     448 if not has_local_code:
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\transformers\dynamic_module_utils.py:581, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568 # And lastly we get the class inside our newly created module
#     569 final_module = get_cached_module_file(
#     570     repo_id,
#     571     module_file + ".py",
#    (...)    579     repo_type=repo_type,
#     580 )
# --> 581 return get_class_in_module(class_name, final_module, force_reload=force_download)
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\transformers\dynamic_module_utils.py:278, in get_class_in_module(class_name, module_path, force_reload)
#     276     module_spec.loader.exec_module(module)
#     277     module.__transformers_module_hash__ = module_hash
# --> 278 return getattr(module, class_name)
#
# AttributeError: module 'transformers_modules.vikhyatk.moondream2.6b714b26eea5cbd9f31e4edb2541c170afa935ba.moondream' has no attribute 'Moondream'
# d:\Attack dataset project\dataset-project\attack_dataset

# %% [markdown]
# # CIFAR10 dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('custom_model')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnist_dnn_cnn_llm_vlm.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Quantum (mnisq) classify mnisq (FashionMnist) dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnisq')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnisq_test.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Custom is **simple**, CIFAR10 is **medium**, and mnisq **complex** dataset
