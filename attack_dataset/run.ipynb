# %% [markdown]
# # MNIST

# %%
import os
import sys

SAMPLE_SIZE = 10000
# 1. Detect OS and set NUM_TEST_SAMPLES environment variable
if sys.platform.startswith("win"):
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # Windows value
elif sys.platform == "darwin":
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # macOS value
else:
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # Linux value


# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnist')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file

# %run mnist_dnn_cnn_test.py

# %run mnist_yolo_test.py
# %run mnist_mobilenet_test.py

# %run mnist_qwen_test.py
# %run mnist_moondream_test.py

# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)
# Out:
# Generating device ID from: CS-541172-Windows-AMD64-Intel(R) Core(TM) i7-10700K CPU @ 3.80GHz
#
# Done.
#
# Collecting 10000 edge samples for CNN on CS-541172
# Device UUID : 9f56743a9725b15f77edc373bff72f5d9a1e7820eff00ab22f83e6c7b2d0b9c3
# Device short: 9f56743a
# CNN: resuming from 0/10000
# CNN:   0%|          | 0/10000 [00:00<?, ?sample/s][codecarbon WARNING @ 17:58:23] Multiple instances of codecarbon are allowed to run at the same time.
# CNN:   0%|          | 1/10000 [00:04<12:08:56,  4.37s/sample, pred=7, true=7, time_s=0.003, done=1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File D:\Attack dataset project\dataset-project\attack_dataset\mnist\mnist_dnn_cnn_test.py:1001
#     991         collect_for_model(
#     992             base_dataset,
#     993             "DNN",
#    (...)    996             file_name=f"attacked_epsilon_{epsilon_percentage}"
#     997         )
#    1000 if __name__ == "__main__":
# -> 1001     main()
#
# File D:\Attack dataset project\dataset-project\attack_dataset\mnist\mnist_dnn_cnn_test.py:943, in main()
#     933 print("\nDone.")
#     936 base_dataset = datasets.MNIST(
#     937     root="./mnist_data",
#     938     train=False,
#     939     download=True,
#     940     transform=transforms.ToTensor()
#     941 )
# --> 943 collect_for_model(base_dataset, "CNN",      num_samples=NUM_TEST_SAMPLES, flush_every=25, file_name ='vanilla')
#     944 collect_for_model(base_dataset, "DNN",      num_samples=NUM_TEST_SAMPLES, flush_every=25, file_name ='vanilla')
#     947 ATTACK_DIR = Path("./mnist_fgsm_splits")
#
# File D:\Attack dataset project\dataset-project\attack_dataset\mnist\mnist_dnn_cnn_test.py:882, in collect_for_model(base_dataset, model_name, num_samples, flush_every, file_name)
#     877 logits = None
#     879 if model_name in ("CNN", "DNN"):
#     880     (pred, logits), exec_time, cpu_energy, gpu_energy, ram_energy, \
#     881         total_energy, emissions_value, carbon_intensity, gpu_snap = \
# --> 882         run_with_energy_tracking(
#     883             _run_torch_model, model, image_tensor
#     884         )
#     886 row = build_row(
#     887     model_name=model_name,
#     888     prediction=pred,
#    (...)    902     model_under_attack= file_name != 'vanilla'
#     903 )
#     905 rows.append(row)
#
# File D:\Attack dataset project\dataset-project\attack_dataset\mnist\mnist_dnn_cnn_test.py:457, in run_with_energy_tracking(inference_fn, output_dir, *args, **kwargs)
#     454 os.makedirs(output_dir, exist_ok=True)
#     456 if CODECARBON_AVAILABLE:
# --> 457     tracker = EmissionsTracker(
#     458         project_name="mnist_edge_inference",
#     459         output_dir=output_dir,
#     460         output_file="codecarbon_dnn_cnn_edge.csv",
#     461         log_level="error",
#     462         save_to_file=True,
#     463     )
#     464     tracker.start()
#     465     t0 = time.perf_counter()
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\codecarbon\emissions_tracker.py:324, in BaseEmissionsTracker.__init__(self, project_name, measure_power_secs, api_call_interval, api_endpoint, api_key, output_dir, output_file, save_to_file, save_to_api, save_to_logger, logging_logger, save_to_prometheus, save_to_logfire, prometheus_url, output_handlers, gpu_ids, emissions_endpoint, experiment_id, experiment_name, co2_signal_api_token, tracking_mode, log_level, on_csv_write, logger_preamble, force_cpu_power, force_ram_power, pue, force_mode_cpu_load, allow_multiple_runs)
#     322 # Tracking mode detection
#     323 ressource_tracker = ResourceTracker(self)
# --> 324 ressource_tracker.set_CPU_GPU_ram_tracking()
#     326 self._conf["hardware"] = list(map(lambda x: x.description(), self._hardware))
#     328 logger.info(">>> Tracker's metadata:")
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\codecarbon\core\resource_tracker.py:214, in ResourceTracker.set_CPU_GPU_ram_tracking(self)
#     209 """
#     210 Set up CPU, GPU and RAM tracking based on the user's configuration.
#     211 param tracker: BaseEmissionsTracker object
#     212 """
#     213 self.set_RAM_tracking()
# --> 214 self.set_CPU_tracking()
#     215 self.set_GPU_tracking()
#     217 logger.info(
#     218     f"""The below tracking methods have been set up:
#     219         RAM Tracking Method: {self.ram_tracker}
#    (...)    222     """
#     223 )
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\codecarbon\core\resource_tracker.py:39, in ResourceTracker.set_CPU_tracking(self)
#      37 logger.info("[setup] CPU Tracking...")
#      38 cpu_number = self.tracker._conf.get("cpu_physical_count")
# ---> 39 tdp = cpu.TDP()
#      40 if self.tracker._force_cpu_power is not None:
#      41     logger.info(
#      42         f"Using user-provided CPU power: {self.tracker._force_cpu_power} Watts"
#      43     )
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\codecarbon\core\cpu.py:389, in TDP.__init__(self)
#     388 def __init__(self):
# --> 389     self.model, self.tdp = self._main()
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\codecarbon\core\cpu.py:488, in TDP._main(self)
#     482 def _main(self) -> Tuple[str, int]:
#     483     """
#     484     Get CPU power from constant mode
#     485
#     486     :return: model name (str), power in Watt (int)
#     487     """
# --> 488     cpu_model_detected = detect_cpu_model()
#     490     if cpu_model_detected:
#     491         power = self._get_cpu_power_from_registry(cpu_model_detected)
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\codecarbon\core\util.py:77, in detect_cpu_model()
#      76 def detect_cpu_model() -> str:
# ---> 77     cpu_info = cpuinfo.get_cpu_info()
#      78     if cpu_info:
#      79         cpu_model_detected = cpu_info.get("brand_raw", "")
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\cpuinfo\cpuinfo.py:2759, in get_cpu_info()
#    2752 '''
#    2753 Returns the CPU info by using the best sources of information for your OS.
#    2754 Returns the result in a dict
#    2755 '''
#    2757 import json
# -> 2759 output = get_cpu_info_json()
#    2761 # Convert JSON to Python with non unicode strings
#    2762 output = json.loads(output, object_hook = _utf_to_str)
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\site-packages\cpuinfo\cpuinfo.py:2742, in get_cpu_info_json()
#    2740 command = [sys.executable, __file__, '--json']
#    2741 p1 = Popen(command, stdout=PIPE, stderr=PIPE, stdin=PIPE)
# -> 2742 output = p1.communicate()[0]
#    2744 if p1.returncode != 0:
#    2745 	return "{}"
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\subprocess.py:1628, in Popen._communicate(self, input, endtime, orig_timeout)
#    1624 # Wait for the reader threads, or time out.  If we time out, the
#    1625 # threads remain reading and the fds left open in case the user
#    1626 # calls communicate again.
#    1627 if self.stdout is not None:
# -> 1628     self.stdout_thread.join(self._remaining_time(endtime))
#    1629     if self.stdout_thread.is_alive():
#    1630         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\SIU856536670\AppData\Local\anaconda3\envs\vlm\Lib\threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:
# ================================================================================
# LOAD-ONLY YOLO26 NANO MNIST CPU TEST
# ================================================================================
# Model: D:\Attack dataset project\dataset-project\attack_dataset\mnist\yolo26n_mnist_cpu.pt
# Training: DISABLED
# Test samples: 10000
# Device: cpu
# Parameters: 1543914
# Model FLOPs: 7748800
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# Testing one-by-one:   0%|          | 0/10000 [00:00<?, ?image/s]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]

# %% [markdown]
# # CIFAR10 dataset

# %%
import os
import sys
SAMPLE_SIZE = 10000
# 1. Detect OS and set NUM_TEST_SAMPLES environment variable
if sys.platform.startswith("win"):
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # Windows value
elif sys.platform == "darwin":
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # macOS value
else:
    os.environ["NUM_TEST_SAMPLES"] = str(SAMPLE_SIZE)   # Linux value

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('cifar10')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run cifar10_dnn_cnn_test.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)
# Out:
# Generating device ID from: CS-541172-Windows-AMD64-Intel(R) Core(TM) i7-10700K CPU @ 3.80GHz
#
# Collecting 10000 CIFAR-10 RGB edge samples for DNN on CS-541172
# Device UUID : 9f56743a9725b15f77edc373bff72f5d9a1e7820eff00ab22f83e6c7b2d0b9c3
# Device short: 9f56743a
# Model FLOPs: 1,737,984
# Parameters: 1738890
# Model FLOPs: 1737984
# DNN: resuming from 0/10000
# DNN-CIFAR10:   0%|          | 0/10000 [00:00<?, ?sample/s][codecarbon WARNING @ 17:59:16] Multiple instances of codecarbon are allowed to run at the same time.
# DNN-CIFAR10:   0%|          | 6/10000 [00:11<5:31:42,  1.99s/sample, pred=6, true=6, time_s=0.001, done=6]

# %% [markdown]
# # Quantum (mnisq) classify mnisq (FashionMnist) dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnisq')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnisq_test.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Custom is **simple**, CIFAR10 is **medium**, and mnisq **complex** dataset
