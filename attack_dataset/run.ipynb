# %% [markdown]
# # MNIST

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnist')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnist_dnn_cnn_test.py

# %run mnist_yolo_test.py
# %run mnist_mobilenet_test.py


# %run mnist_qwen_test.py
# %run mnist_moondream_test.py

# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)
# Out:
# Generating device ID from: CS-541172-Windows-AMD64-Intel(R) Core(TM) i7-10700K CPU @ 3.80GHz
#
# Collecting 10 edge samples for CNN on CS-541172
# Device UUID : 9f56743a9725b15f77edc373bff72f5d9a1e7820eff00ab22f83e6c7b2d0b9c3
# Device short: 9f56743a
# CNN: resuming from 0/10
# CNN:   0%|          | 0/10 [00:00<?, ?sample/s][codecarbon WARNING @ 18:02:17] Multiple instances of codecarbon are allowed to run at the same time.
# CNN: 100%|██████████| 10/10 [00:22<00:00,  2.26s/sample, pred=9, true=9, time_s=0.002, done=10]
# CNN: finished 10/10 -> d:\Attack dataset project\dataset-project\attack_dataset\mnist\test_results\9f56743a\fingerprint_dataset_9f56743a_automated_edge.csv
#
# Collecting 10 edge samples for DNN on CS-541172
# Device UUID : 9f56743a9725b15f77edc373bff72f5d9a1e7820eff00ab22f83e6c7b2d0b9c3
# Device short: 9f56743a
# DNN: resuming from 0/10
# DNN: 100%|██████████| 10/10 [00:22<00:00,  2.24s/sample, pred=9, true=9, time_s=0.001, done=10]
# DNN: finished 10/10 -> d:\Attack dataset project\dataset-project\attack_dataset\mnist\test_results\9f56743a\fingerprint_dataset_9f56743a_automated_edge.csv
#
# Done.
# ================================================================================
# LOAD-ONLY YOLO26 NANO MNIST CPU TEST
# ================================================================================
# Model: D:\Attack dataset project\dataset-project\attack_dataset\mnist\yolo26n_mnist_cpu.pt
# Training: DISABLED
# Test samples: 10
# Device: cpu
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# Testing one-by-one:   0%|          | 0/10 [00:00<?, ?image/s]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
# WARNING imgsz=[28] must be multiple of max stride 32, updating to [32]
#
# ================================================================================
# TEST RESULTS
# ================================================================================
# Accuracy: 0.1000
# Macro F1: 0.0182
# Weighted F1: 0.0182
# Average inference time: 0.019451 sec
#
# RETURN FILES
# model_pt: D:\Attack dataset project\dataset-project\attack_dataset\mnist\yolo26n_mnist_cpu.pt
# test_telemetry_csv: D:\Attack dataset project\dataset-project\attack_dataset\mnist\test_results\9f56743a\yolo_test_telemetry_1000.csv
# ======================================================================
# MOBILENETV2 MNIST TEST WITH FULL TELEMETRY
# ======================================================================
# Device: cuda
# Samples: 10
# Parameters: 2236682
# FLOPs: 312926016
# Testing: 100%|██████████| 10/10 [00:23<00:00,  2.32s/it]
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Accuracy:           0.2000
# Weighted Precision: 0.0667
# Weighted Recall:    0.2000
# Weighted F1:        0.1000
# Macro F1:           0.1000
#
# Confusion matrix:
#
# Telemetry CSV: d:\Attack dataset project\dataset-project\attack_dataset\mnist\test_results\9f56743a\mobilenet_v2_mnist_test_full_telemetry.csv
#
# Loading MNIST...
# Test samples: 10000
#
# Loading: Qwen/Qwen2-VL-2B-Instruct
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Parameters: 2,208,985,600
#
# Testing Qwen2-VL-2B-Instruct
# Samples: 10
# Device: cuda
# Qwen2-VL MNIST: 100%|██████████| 10/10 [00:23<00:00,  2.38s/sample]
# =================================
# Qwen2-VL MNIST TEST RESULTS
# =================================
# Samples   : 10
# Accuracy  : 0.5000
# Precision : 0.5571
# Recall    : 0.5000
# F1        : 0.4556
#
# Saved to:
# d:\Attack dataset project\dataset-project\attack_dataset\mnist\test_results\9f56743a\qwen2vl_mnist_test_telemetry.csv
# d:\Attack dataset project\dataset-project\attack_dataset

# %% [markdown]
# # CIFAR10 dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('custom_model')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnist_dnn_cnn_llm_vlm.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Quantum (mnisq) classify mnisq (FashionMnist) dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnisq')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnisq_test.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Custom is **simple**, CIFAR10 is **medium**, and mnisq **complex** dataset
