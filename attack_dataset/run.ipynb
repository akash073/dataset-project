# %% [markdown]
# # MNIST

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnist')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file

# %run mnist_dnn_cnn_test.py

# %run mnist_yolo_test.py

# %run mnist_mobilenet_test.py

# %run mnist_qwen_test.py
# %run mnist_moondream_test.py

# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)
# Out:
# Loading MNIST...
# Test samples: 10000
#
# Loading: Qwen/Qwen2-VL-2B-Instruct
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Parameters: 2,208,985,600
#
# Testing Qwen2-VL-2B-Instruct
# Samples: 10
# Device: cuda
# Qwen2-VL MNIST: 100%|██████████| 10/10 [00:21<00:00,  2.19s/sample]
# =================================
# Qwen2-VL MNIST TEST RESULTS
# =================================
# Samples   : 10
# Accuracy  : 0.5000
# Precision : 0.5571
# Recall    : 0.5000
# F1        : 0.4556
#
# Saved to:
# d:\Attack dataset project\dataset-project\attack_dataset\mnist\test_results\9f56743a\qwen2vl_mnist_test_telemetry.csv
# ========================================================================
# TEST CONFIGURATION
# ========================================================================
# Transformers: 4.56.1
# Model: fal/moondream2-docci-instruct
# Revision: 3ec40c7b6b5d87bc0c51edee45e21f5f29b449d8
# Device: cuda
# Data type: torch.bfloat16
# GPU: NVIDIA GeForce RTX 4070 Ti SUPER
#
# Loading tokenizer...
# Tokenizer loaded.
#
# Loading fal/moondream2-docci-instruct directly...
# Forced AutoModel implementation: moondream.Moondream
# PhiForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly defined. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Applied GenerationMixin compatibility patch.
# Applied PhiForCausalLM forward compatibility patch.
#
# Model ready.
# Model parameters: 1,857,482,608
#
# Number of MNIST test images: 10
#
# Running warm-up inference...
# Warm-up response: A close up view of a white handwritten number "7" in the middle of the image. The number is slightly blurry. The number is in a black background. The number is slightly blurry.
# Warm-up completed successfully.
#
# ========================================================================
# TESTING MOONDREAM2 DoCCI INSTRUCT ON MNIST
# ========================================================================
# Testing:   0%|          | 0/10 [00:00<?, ?it/s]
# Image 1/10
# True label:  7
# Prediction:  7
# Raw answer:  A close up view of a white handwritten number "7" in the middle of the image. The number is slightly blurry. The number is in a black background. The number is slightly blurry.
# Confidence:  0.17277786135673523
# Correct:     True
# Latency:     2.8284 seconds
#
# Image 2/10
# True label:  2
# Prediction:  2
# Raw answer:  A close-up view of a white handwritten number "2" in the middle of the image. The number is slightly blurry. The number is in a black and white image. The number is in the middle of the image. The number is slightly blurry. The number is in the middle of the image. The number is slightly blurry. The number is in the middle of the image. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number is slightly blurry. The number
# Confidence:  0.12055270373821259
# Correct:     True
# Latency:     20.3815 seconds
#
# Image 3/10
# True label:  1
# Prediction:  0
# Raw answer:  A close-up view of a white handwritten number "0" in the middle of the image. The number is in a black background. The number is slightly blurry. The number is in the middle of the image. The number is a thin line. It is slightly blurry. The number is in the middle of the image. The number is in the middle of the image.
# Confidence:  0.11043206602334976
# Correct:     False
# Latency:     4.5404 seconds
#
# Image 4/10
# True label:  0
# Prediction:  invalid
# Raw answer:  A close up view of a white circle with a white outline. The circle is slightly blurry. The circle is in the middle of a black background. The circle is slightly blurry.
# Confidence:  0.0
# Correct:     False
# Latency:     2.4619 seconds
#
# Image 5/10
# True label:  4
# Prediction:  4
# Raw answer:  A close-up view of a white handwritten number "4" in the middle of the image. The number is slightly blurry. The number is in a black background. The number is slightly blurry.
# Confidence:  0.09117937088012695
# Correct:     True
# Latency:     2.6645 seconds
#
# Image 6/10
# True label:  1
# Prediction:  0
# Raw answer:  A close up view of a white handwritten number "0" in the center of the image. The number is slightly blurry. The number is in a black background. The number is slightly blurry.
# Confidence:  0.13182805478572845
# Correct:     False
# Latency:     2.6372 seconds
#
# Image 7/10
# True label:  4
# Prediction:  4
# Raw answer:  A close-up view of a white handwritten number "4" in the middle of the image. The "4" is slightly blurry. The "4" is in a black background. The "4" is casting a shadow over the "4" and the background.
# Confidence:  0.08880574256181717
# Correct:     True
# Latency:     2.9932 seconds
#
# Image 8/10
# True label:  9
# Prediction:  6
# Raw answer:  A close up view of a white handwritten number "6" in the middle of the image. The number is slightly blurry. The number is in the middle of the image, and it is slightly blurry. The number is in a black background.
# Confidence:  0.06646387279033661
# Correct:     False
# Latency:     2.8842 seconds
#
# Image 9/10
# True label:  5
# Prediction:  6
# Raw answer:  A close-up view of a white handwritten number "6" in the middle of the image. The number is slightly blurry. The number is in a black background. The number is slightly blurry.
# Confidence:  0.0528172142803669
# Correct:     False
# Latency:     2.4581 seconds

# %% [markdown]
# # CIFAR10 dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('custom_model')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnist_dnn_cnn_llm_vlm.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Quantum (mnisq) classify mnisq (FashionMnist) dataset

# %%
import os

# Save current directory
original_dir = os.getcwd()

# Change to target directory
executed_dir = os.chdir('mnisq')

#print(executed_dir)  # This will print None because os.chdir() does not return the new directory
# Run the file
# %run mnisq_test.py


# Check you're in the right place
print(original_dir)
# Optional: Change back to original directory
os.chdir(original_dir)

# %% [markdown]
# # Custom is **simple**, CIFAR10 is **medium**, and mnisq **complex** dataset
